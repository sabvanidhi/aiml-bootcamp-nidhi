# %% [markdown]
# # Task-1

# %%
abc=[10,20,30,40,50]
#loop
for n in abc:
    a=n*n
    print(a)
#functional
a=[n*n for n in abc]
print(a)
# Out:
# 100
# 400
# 900
# 1600
# 2500
# [100, 400, 900, 1600, 2500]

# %%
a=['python ','html','css','java']
b=[]
c=[]
#loop
for n in a:
    b.append(n.upper())
print(b)

for n in a:
    c.append(n.strip())
print(c)

# functional

abc=list(n.upper() for n in a)

pqr=[n.strip() for n in a]
print(abc)
print(pqr)
# Out:
# ['PYTHON ', 'HTML', 'CSS', 'JAVA']
# ['python', 'html', 'css', 'java']
# ['PYTHON ', 'HTML', 'CSS', 'JAVA']
# ['python', 'html', 'css', 'java']

# %%
a=[1,2,3,4]
b=[5,6,7,8]
#loop


#functional
z=list(map(lambda a,b:a*b,a,b))

print(z)
# Out:
# [5, 12, 21, 32]

# %%
b=['python','css','html','java','mathametic']
#loop
#functional
a=list(filter(lambda word: len(word) >  4,b))
print(a)
# Out:
# ['python', 'mathametic']

# %%
from functools import reduce
#loop
#functional
a=[10,20,30,40,50,60]

b=reduce(lambda x,y:x+y,a)
print(b)
# Out:
# 210

# %%
list=[
    {"item":"abc","price":30},
    {"item":"xyz","price":90},
    {"item":"aaa","price":76},
    {"item":"bbb","price":40}
    ]
#loop
#functional
b=sum(map(lambda list:list["price"],list))

print(b)
# Out:
# 236

# %%
from itertools import chain
#loop
#functional
print(list(chain([1, 2], [3, 4], [5])))
# Out:
# [1, 2, 3, 4, 5]

# %%
from collections import Counter
#loop
#functional
b=['python','css','html','java','mathametic']

a=dict(map(lambda x:(x,len(x)),b))

print(a)
# Out:
# {'python': 6, 'css': 3, 'html': 4, 'java': 4, 'mathametic': 10}

# %%
l1=["",None,[],'abc','def','xyz']
#loop
#functional
list(filter(None,l1))
# Out:
# ['abc', 'def', 'xyz']

# %%
from itertools import accumulate
abc=[10,20,30,40,50,60]
#loop
#functional
print(list(accumulate(abc)))
# Out:
# [10, 30, 60, 100, 150, 210]

# %% [markdown]
# # Task-2

# %%
with open("abc.txt","w") as f:
    f.write("hello! This is a Day3 Python refresher class. This is a python class. This is a python refresher class.")

# %%
from collections import Counter
with open("abc.txt","r") as f:
    text=f.read().lower().split()
    dictionary={}
    for word in text:
        dictionary[word]=dictionary.get(word,0)+1
print(dictionary)
# Out:
# {'hello!': 1, 'this': 3, 'is': 3, 'a': 3, 'day3': 1, 'python': 3, 'refresher': 2, 'class.': 3}

# %%
from collections import Counter
import string

with open("abc.txt", "r") as f:
    text = f.read().lower()

    text = text.translate(
        str.maketrans("", "", string.punctuation)
    )
    words = text.split()
    stopwords = {
    "the", "a", "an", "is", "and",
    "of", "to", "in", "for", "on"
}
new_words = []
for i in words:
    if i not in stopwords:
        new_words.append(i)

words = new_words
counter = Counter(words)
print(counter)
print(counter.most_common(3))
# Out:
# Counter({'this': 3, 'python': 3, 'class': 3, 'refresher': 2, 'hello': 1, 'day3': 1})
# [('this', 3), ('python', 3), ('class', 3)]

# %%
from itertools import combinations,permutations,product
student=["abc","xyz","pqr","lmn","def"]
print("Combinations of 2 students:")
print(list(combinations(student, 2)))
print("Combinations of 3 students:")
print(list(combinations(student, 3)))
print("Permutations of 2 students:")
print(list(permutations(student, 2)))
print("Product of colors and sizes:")
print(list(product([["red"], ["blue"], ["green"]],[["small"], ["medium"], ["large"]])))
# Out:
# Combinations of 2 students:
# [('abc', 'xyz'), ('abc', 'pqr'), ('abc', 'lmn'), ('abc', 'def'), ('xyz', 'pqr'), ('xyz', 'lmn'), ('xyz', 'def'), ('pqr', 'lmn'), ('pqr', 'def'), ('lmn', 'def')]
# Combinations of 3 students:
# [('abc', 'xyz', 'pqr'), ('abc', 'xyz', 'lmn'), ('abc', 'xyz', 'def'), ('abc', 'pqr', 'lmn'), ('abc', 'pqr', 'def'), ('abc', 'lmn', 'def'), ('xyz', 'pqr', 'lmn'), ('xyz', 'pqr', 'def'), ('xyz', 'lmn', 'def'), ('pqr', 'lmn', 'def')]
# Permutations of 2 students:
# [('abc', 'xyz'), ('abc', 'pqr'), ('abc', 'lmn'), ('abc', 'def'), ('xyz', 'abc'), ('xyz', 'pqr'), ('xyz', 'lmn'), ('xyz', 'def'), ('pqr', 'abc'), ('pqr', 'xyz'), ('pqr', 'lmn'), ('pqr', 'def'), ('lmn', 'abc'), ('lmn', 'xyz'), ('lmn', 'pqr'), ('lmn', 'def'), ('def', 'abc'), ('def', 'xyz'), ('def', 'pqr'), ('def', 'lmn')]
# Product of colors and sizes:
# [(['red'], ['small']), (['red'], ['medium']), (['red'], ['large']), (['blue'], ['small']), (['blue'], ['medium']), (['blue'], ['large']), (['green'], ['small']), (['green'], ['medium']), (['green'], ['large'])]

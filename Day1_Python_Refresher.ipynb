# %% [markdown]
# # Task-4

# %%
for i in range(1, 101):
    if i%15==0:
        print("FizzBuzz")
    elif i%3==0:
        print("Fizz")
    elif i%5==0:
        print("Buzz")
    else:
        print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz

# %%
for i in range(1, 101):
    if i%15==0:
        print("FizzBuzz")
    elif i%3==0:
        print("Fizz")
    elif i%5==0:
        print("Buzz")
    elif i%7==0:
        print("FizzBuzzBazz")
    else:
        print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# FizzBuzzBazz
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# FizzBuzzBazz
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# FizzBuzzBazz
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# FizzBuzzBazz
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# FizzBuzzBazz
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# FizzBuzzBazz
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# FizzBuzzBazz
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# FizzBuzzBazz
# Fizz
# Buzz

# %%
result = [
    "FizzBuzz" if i%15==0
    else "Fizz" if i%3==0
    else "Buzz" if i%5==0
    else i
    for i in range(1,101)
]

print(result)
# Out:
# [1, 2, 'Fizz', 4, 'Buzz', 'Fizz', 7, 8, 'Fizz', 'Buzz', 11, 'Fizz', 13, 14, 'FizzBuzz', 16, 17, 'Fizz', 19, 'Buzz', 'Fizz', 22, 23, 'Fizz', 'Buzz', 26, 'Fizz', 28, 29, 'FizzBuzz', 31, 32, 'Fizz', 34, 'Buzz', 'Fizz', 37, 38, 'Fizz', 'Buzz', 41, 'Fizz', 43, 44, 'FizzBuzz', 46, 47, 'Fizz', 49, 'Buzz', 'Fizz', 52, 53, 'Fizz', 'Buzz', 56, 'Fizz', 58, 59, 'FizzBuzz', 61, 62, 'Fizz', 64, 'Buzz', 'Fizz', 67, 68, 'Fizz', 'Buzz', 71, 'Fizz', 73, 74, 'FizzBuzz', 76, 77, 'Fizz', 79, 'Buzz', 'Fizz', 82, 83, 'Fizz', 'Buzz', 86, 'Fizz', 88, 89, 'FizzBuzz', 91, 92, 'Fizz', 94, 'Buzz', 'Fizz', 97, 98, 'Fizz', 'Buzz']

# %%
result = [
    "FizzBuzz" if i%15==0
    else "FizzBuzzBazz" if i%7==0
    else "Fizz" if i% 3==0
    else "Buzz" if i%5==0
    else i
    for i in range(1,101)
]

print(result)
# Out:
# [1, 2, 'Fizz', 4, 'Buzz', 'Fizz', 'FizzBuzzBazz', 8, 'Fizz', 'Buzz', 11, 'Fizz', 13, 'FizzBuzzBazz', 'FizzBuzz', 16, 17, 'Fizz', 19, 'Buzz', 'FizzBuzzBazz', 22, 23, 'Fizz', 'Buzz', 26, 'Fizz', 'FizzBuzzBazz', 29, 'FizzBuzz', 31, 32, 'Fizz', 34, 'FizzBuzzBazz', 'Fizz', 37, 38, 'Fizz', 'Buzz', 41, 'FizzBuzzBazz', 43, 44, 'FizzBuzz', 46, 47, 'Fizz', 'FizzBuzzBazz', 'Buzz', 'Fizz', 52, 53, 'Fizz', 'Buzz', 'FizzBuzzBazz', 'Fizz', 58, 59, 'FizzBuzz', 61, 62, 'FizzBuzzBazz', 64, 'Buzz', 'Fizz', 67, 68, 'Fizz', 'FizzBuzzBazz', 71, 'Fizz', 73, 74, 'FizzBuzz', 76, 'FizzBuzzBazz', 'Fizz', 79, 'Buzz', 'Fizz', 82, 83, 'FizzBuzzBazz', 'Buzz', 86, 'Fizz', 88, 89, 'FizzBuzz', 'FizzBuzzBazz', 92, 'Fizz', 94, 'Buzz', 'Fizz', 97, 'FizzBuzzBazz', 'Fizz', 'Buzz']

# %%
#I would use both versions.If the condition is simple I would use the comprehension version. 
#If the conditions is complex, I would use the normal version.

# %%
#A clever one-liner is worth using when the logic is simple and easy to understand. 
#If the one-liner becomes complicated or difficult to read, it is better to use multiple lines.

# %%
#i%3==0 checks whether i is divisible by 3. If the remainder is 0,it means i is a multiple of 3.

# %% [markdown]
# # Task-5

# %%
def reverse_words(sentence):
    words = sentence.split()
    words = words[::-1]
    return ' '.join(words)

sentence = input("Enter a sentence: ")
print(reverse_words(sentence))
# Out:
# sentence is this

# %%
def count_word(sentence):
    words=sentence.split()
    count= {}

    for i in words:
        if i in count:
            count[i]+=1
        else:
            count[i]=1
    return count

sentence = input("Enter a sentence: ")
print(count_word(sentence))
# Out:
# {'abc': 3, 'def': 2, 'ghi': 2, 'xyz': 1}

# %%
nums=[20,11,4,7,8,9,22,24]
print([x*2 for x in nums if x % 2 == 0])
# Out:
# [40, 8, 16, 44, 48]

# %%
item=[10,20,30,10,30,40,20,10]
print(sorted(set(item)))
# Out:
# [10, 20, 30, 40]

# %%
word=input('enter a word:')
if word==word[::-1]:
    print('this word is palindrom')
else:
    print("this is not a palindrom")
# Out:
# this word is palindrom

# %%
#word[::-1] reverses a string. It shows the string from backward to forward.

# %%
#a dictionary stores key-value pairs, so we can easily store each word and its count.

# %%
#if we have a duplicate value then use a set because set not contain any duplicate values

# %% [markdown]
# # Task-6

# %%
numbers=[10,20,30,40,11,34,23]

def  calculate_stats(numbers):
    dict={ "min_number":min(numbers),
          "max_number":max(numbers),
          "mean_number":sum(numbers)/len(numbers),
          "count_number":len(numbers)}
    return dict
print(calculate_stats(numbers))
# Out:
# {'min_number': 10, 'max_number': 40, 'mean_number': 24.0, 'count_number': 7}

# %%
def safe_divide(a,b):
    try:
        return a/b
    except ZeroDivisionError:
        return "Cannot divide by zero"
print(safe_divide(10,2))
print(safe_divide(10,0))
# Out:
# 5.0
# Cannot divide by zero

# %%
#dictionay have a key value pair so we can easy to undersatnd

# %%
#We should not catch every error. We should handle only the specific error.

# %% [markdown]
# # Hint Type

# %%
def reverce_sentance(sentance:str)->str:
    word=sentance.split()
    word=word[::-1]
    return " ".join(word)

sentance=input("enter a sentance:")
print(reverce_sentance(sentance))
# Out:
# def abc

# %%
def count_word(sentance:str)->str:
    word=sentance.split()
    count={}

    for i in word:
        if i in count:
            count[i]+=1
        else:
            count[i]=1
    return count

sentance=input("enter a sentance:")
print(count_word(sentance))
# Out:
# {'abc': 4, 'def': 1, 'ghi': 1}

# %%
l=[10,11,44,32,98,34,76,89,12,98]

for i in l:
    if(i%2)==0:
        print(i*2)
# Out:
# 20
# 88
# 64
# 196
# 68
# 152
# 24
# 196

# %%
number=[10,32,55,43,98,77,21,32]

def calculate_stats(number: list)-> dict:
        dic={
            "min":min(number),
            "mix":max(number),
            "avg":sum(number)/len(number),
            "count":len(number)
        }

        return dic

print(calculate_stats(number))
# Out:
# {'min': 10, 'mix': 98, 'avg': 46.0, 'count': 8}

# %%
def safe_divide(a:int, b:int)->int:
    try:
        return a/b
    except ZeroDivisionError:
        return "zero is not divide"

a=int(input("enter a number:"))
b=int(input("enter a number"))
print(safe_divide(a,b))
# Out:
# 0.5
